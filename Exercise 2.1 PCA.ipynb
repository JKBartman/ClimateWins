# %% [markdown]
# # Exercise 2.1 PCA

# %% [markdown]
# ## Index
# ### Import Libraries and Data
# ### Reduce Data
# ### Dendrograms

# %% [markdown]
# ## Import Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
path = r'C:/Users/Jack Bartman/OneDrive/CareerFoundry/Machine Learning'

# %%
# Import data
dfyear =pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', '1986_PCA.csv'))

# %%
dfyear
# Out:
#            PCA1        PCA2       PCA3       PCA4       PCA5       PCA6  \
# 0   -570.643153  -56.504047 -15.811149  -6.074916 -17.344088 -12.793349
# 1   -568.532232  -35.592010  -5.747912   7.225294 -20.453503 -11.385675
# 2   -566.964330  -22.901421 -13.049035   8.982099 -16.752535  -8.854362
# 3   -566.751024  -35.432844 -17.980362  -2.446879 -15.711488   0.386716
# 4   -566.007148  -43.461021  -8.450348   5.372791 -18.793055 -12.710334
# ..          ...         ...        ...        ...        ...        ...
# 360  553.798712 -103.081021  23.863770   7.432562  22.005822  15.091959
# 361  555.284845  -92.917538  20.464985  17.241580  25.192137  13.044825
# 362  556.993452  -74.893877  19.867096  28.157159  34.955221  11.988358
# 363  558.225850  -69.486303   8.064840  29.999743  41.006912   0.767170
# 364  558.923141  -76.217362   7.730688  31.245623  38.753152  -2.377767
#
#           PCA7       PCA8      PCA9
# 0    12.143752  -9.998841  6.837723
# ...

# %% [markdown]
# ## Dendrograms

# %% [markdown]
# ###   Single Method - Unscaled

# %%
distance_single = linkage(dfyear.loc[:,
['PCA1',
 'PCA2',
 'PCA3',
 'PCA4',
 'PCA5',
 'PCA6',
 'PCA7',
 'PCA8',
 'PCA9']],method="single")
plt.figure(figsize=(30,10))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Single Method - Unscaled",fontsize=18)
plt.show()

# %%
# 12 clusters found

# %% [markdown]
# ### Complete - Unscaled

# %%
distance_single = linkage(dfyear.loc[:,
['PCA1',
 'PCA2',
 'PCA3',
 'PCA4',
 'PCA5',
 'PCA6',
 'PCA7',
 'PCA8',
 'PCA9']],method="complete")
plt.figure(figsize=(30,10))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Complete Method - Complete",fontsize=18)
plt.show()

# %%
# 2 clusters found

# %% [markdown]
# ### Average - Unscaled

# %%
distance_single = linkage(dfyear.loc[:,
['PCA1',
 'PCA2',
 'PCA3',
 'PCA4',
 'PCA5',
 'PCA6',
 'PCA7',
 'PCA8',
 'PCA9']],method="average")
plt.figure(figsize=(30,10))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Average Method - Average",fontsize=18)
plt.show()

# %%
# 2 clusters found

# %% [markdown]
# ### Ward - Unscaled

# %%
distance_single = linkage(dfyear.loc[:,
['PCA1',
 'PCA2',
 'PCA3',
 'PCA4',
 'PCA5',
 'PCA6',
 'PCA7',
 'PCA8',
 'PCA9']],method="ward")
plt.figure(figsize=(30,10))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Ward Method - Ward",fontsize=18)
plt.show()

# %%
# 2 clusters
